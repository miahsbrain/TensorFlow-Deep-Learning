# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pwd
# Out:
# 'C:\\Users\\Nagant\\Desktop\\AIML\\tut01\\TF_2_Notebooks_and_Data\\01-Pandas-Crash-Course'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 66BD-2FF9
#
#  Directory of C:\Users\Nagant\Desktop\AIML\tut01\TF_2_Notebooks_and_Data\01-Pandas-Crash-Course
#
# 02/26/2024  11:17 PM    <DIR>          .
# 02/23/2024  09:23 PM    <DIR>          ..
# 02/26/2024  11:11 PM    <DIR>          .ipynb_checkpoints
# 11/22/2019  07:57 AM             1,565 00-Intro-to-Pandas.ipynb
# 11/22/2019  07:57 AM             9,345 01-Series.ipynb
# 02/26/2024  10:11 PM            64,442 02-DataFrames.ipynb
# 02/26/2024  09:35 PM            15,159 03-Missing-Data.ipynb
# 02/26/2024  10:04 PM            34,080 04-Groupby.ipynb
# 02/26/2024  10:33 PM            58,521 05-Operations.ipynb
# 02/26/2024  11:10 PM            20,195 06-Data-Input-and-Output.ipynb
# 11/22/2019  07:57 AM            33,507 07-Pandas-Exercises.ipynb
# 11/22/2019  07:57 AM            34,240 08-Pandas-Exercises-Solutions.ipynb
# 11/22/2019  07:57 AM            66,984 african_econ_crises.csv
# ...

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('output.csv', index=False)

# %%
pd.read_csv('output.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
tables = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
type(tables)
# Out:
# list

# %%
tables = tables[0]

# %%
tables.head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539

# %%
tables.columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
tables.groupby('StateSt').count()
# Out:
#          Bank NameBank  CityCity  CertCert  Acquiring InstitutionAI  \
# StateSt
# AL                   7         7         7                        7
# AR                   4         4         4                        4
# AZ                  16        16        16                       16
# CA                  43        43        43                       43
# CO                  10        10        10                       10
# CT                   2         2         2                        2
# FL                  76        76        76                       76
# GA                  93        93        93                       93
# HI                   1         1         1                        1
# IA                   3         3         3                        3
# ID                   2         2         2                        2
# IL                  69        69        69                       69
# IN                   3         3         3                        3
# ...
