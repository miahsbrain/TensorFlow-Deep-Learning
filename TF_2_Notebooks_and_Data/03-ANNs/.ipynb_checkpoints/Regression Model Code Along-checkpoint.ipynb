# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/kc_house_data.csv')

# %%
# df.isnull().sum()

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
sns.displot(df, x='price', aspect=2)

# %%
sns.countplot(df, x='bedrooms', hue='bedrooms', palette='tab20')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
new_df = df.drop('date', axis=1)

# %%
new_df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
new_df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df, x='price', y='sqft_living')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df, x='bedrooms', y='price', hue='bedrooms', palette='tab20')
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df, x='price', y='long')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df, x='price', y='lat')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df, x='long', y='lat', hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
len(df) * 0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(non_top_1_perc, x='long', y='lat', hue='price', edgecolors='none', alpha=0.2, palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(non_top_1_perc, x='waterfront', y='price', hue='waterfront')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id', axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df.groupby('month')['price'].describe()
# Out:
#         count           mean            std       min       25%       50%  \
# month
# 1       978.0  525963.251534  366325.078718   99000.0  310162.5  438500.0
# 2      1247.0  508520.051323  326338.143596   89950.0  309000.0  426500.0
# 3      1875.0  544057.683200  355261.128306   81000.0  319925.0  450000.0
# 4      2229.0  562215.615074  370185.322477   84000.0  338900.0  477000.0
# 5      2414.0  550849.746893  373123.107895   78000.0  330000.0  462000.0
# 6      2178.0  557534.318182  388214.092347   92000.0  330000.0  465000.0
# 7      2211.0  544892.161013  346984.162150   86500.0  325000.0  465000.0
# 8      1939.0  536655.212481  370833.668388  107000.0  324848.5  442200.0
# 9      1771.0  529723.517787  372878.789713   85000.0  325000.0  450000.0
# 10     1876.0  539439.447228  399559.604134   89000.0  315000.0  447000.0
# 11     1409.0  522359.903478  356118.986556   82000.0  308625.0  435000.0
# 12     1470.0  524799.902041  353687.708316   95000.0  312500.0  432500.0
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df, x='month', y='price', hue='month', palette='tab20')
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month')['price'].mean()
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('month')['price'].mean().plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year')['price'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df = df.drop('date', axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %%
X = df.drop('price', axis=1).values

# %%
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=128, epochs=400)
# Out:
# Epoch 1/400
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 119/119 [==============================] - 2s 5ms/step - loss: 430237319168.0000 - val_loss: 418906898432.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 4ms/step - loss: 429304348672.0000 - val_loss: 415816122368.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 4ms/step - loss: 417764704256.0000 - val_loss: 390210027520.0000
# Epoch 4/400
# 119/119 [==============================] - 1s 4ms/step - loss: 363190124544.0000 - val_loss: 299697831936.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 235839340544.0000 - val_loss: 154572898304.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 4ms/step - loss: 121593077760.0000 - val_loss: 97207189504.0000
# ...

# %%
train_hist = pd.DataFrame(model.history.history)

# %%
train_hist
# Out:
#              loss      val_loss
# 0    4.302373e+11  4.189069e+11
# 1    4.293043e+11  4.158161e+11
# 2    4.177647e+11  3.902100e+11
# 3    3.631901e+11  2.996978e+11
# 4    2.358393e+11  1.545729e+11
# ..            ...           ...
# 395  2.956204e+10  2.733868e+10
# 396  2.950676e+10  2.725638e+10
# 397  2.952065e+10  2.728957e+10
# 398  2.954230e+10  2.723898e+10
# 399  2.951329e+10  2.723063e+10
#
# [400 rows x 2 columns]

# %%
train_hist.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
predictions
# Out:
# array([[401378.78],
#        [577959.5 ],
#        [572038.5 ],
#        ...,
#        [398439.72],
#        [564158.1 ],
#        [679732.8 ]], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 165017.06766953843

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 101522.42426094714

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7947171013249008

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
X_train
# Out:
# array([[0.3       , 0.08      , 0.19855222, ..., 0.00657863, 0.        ,
#         0.72727273],
#        [0.2       , 0.28      , 0.1302999 , ..., 0.00288289, 0.        ,
#         0.45454545],
#        [0.3       , 0.48      , 0.25646329, ..., 0.00588823, 1.        ,
#         0.36363636],
#        ...,
#        [0.1       , 0.2       , 0.14788004, ..., 0.00786147, 1.        ,
#         0.27272727],
#        [0.2       , 0.24      , 0.11685626, ..., 0.01557367, 1.        ,
#         0.27272727],
#        [0.1       , 0.08      , 0.08169597, ..., 0.00515118, 1.        ,
#         0.        ]])

# %%
single_house.values.reshape(-1,19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01]])

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 77ms/step
# array([[279394.5]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
