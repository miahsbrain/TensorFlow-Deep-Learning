# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../Pierian_Data_Logo.PNG"></a>
# <strong><center>Copyright by Pierian Data Inc.</center></strong>
# <strong><center>Created by Jose Marcial Portilla.</center></strong>

# %% [markdown]
# # Tensorboard
#
# ---
# ---
#
# **NOTE: You must watch the corresponding video to understand this lecture. This notebook can't serve as a full guide. Please watch the video BEFORE posting questions to the QA forum.**
#
# ---
# ---
#
# Let's explore the built in data visualization capabilities that come with Tensorboard.
#
# Full official tutorial available here: https://www.tensorflow.org/tensorboard/get_started
#
# ## Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
# Out:
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
pwd
# Out:
# 'C:\\Users\\Nagant\\Desktop\\AIML\\tut01\\TF_2_Notebooks_and_Data\\03-ANNs'

# %% [markdown]
# ## Creating the Tensorboard Callback
#
# TensorBoard is a visualization tool provided with TensorFlow.
#
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=path_to_your_logs
# ```
#
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#         update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2024-02-29--1630'

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = 'logs\\fit'

# OPTIONAL: ADD A TIMESTAMP FOR UNIQUE FOLDER
# timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
# log_directory = log_directory + '\\' + timestamp


board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)

# %% [markdown]
# Now create the model layers:

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
# WARNING:tensorflow:From C:\Users\Nagant\anaconda3\envs\mytfenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 14/14 [==============================] - 2s 64ms/step - loss: 0.7029 - val_loss: 0.6754
# Epoch 2/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.6732 - val_loss: 0.6590
# Epoch 3/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.6704 - val_loss: 0.6446
# Epoch 4/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.6439 - val_loss: 0.6278
# Epoch 5/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.6247 - val_loss: 0.6066
# Epoch 6/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.6045 - val_loss: 0.5810
# Epoch 7/600
# 14/14 [==============================] - 0s 37ms/step - loss: 0.5918 - val_loss: 0.5515
# Epoch 8/600
# 14/14 [==============================] - 1s 40ms/step - loss: 0.5714 - val_loss: 0.5199
# Epoch 9/600
# 14/14 [==============================] - 0s 33ms/step - loss: 0.5226 - val_loss: 0.4882
# Epoch 10/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.5245 - val_loss: 0.4533
# Epoch 11/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.5094 - val_loss: 0.4272
# Epoch 12/600
# 14/14 [==============================] - 1s 48ms/step - loss: 0.4519 - val_loss: 0.3959
# Epoch 13/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.4493 - val_loss: 0.3675
# Epoch 14/600
# 14/14 [==============================] - 0s 29ms/step - loss: 0.4184 - val_loss: 0.3423
# Epoch 15/600
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3708 - val_loss: 0.3160
# Epoch 16/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3934 - val_loss: 0.2958
# Epoch 17/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.3798 - val_loss: 0.2789
# Epoch 18/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3482 - val_loss: 0.2630
# Epoch 19/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.3404 - val_loss: 0.2507
# Epoch 20/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.3417 - val_loss: 0.2428
# Epoch 21/600
# 14/14 [==============================] - 0s 23ms/step - loss: 0.3209 - val_loss: 0.2313
# Epoch 22/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.3048 - val_loss: 0.2178
# Epoch 23/600
# 14/14 [==============================] - 0s 26ms/step - loss: 0.2996 - val_loss: 0.2075
# Epoch 24/600
# 14/14 [==============================] - 0s 32ms/step - loss: 0.2814 - val_loss: 0.1990
# Epoch 25/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.2818 - val_loss: 0.1962
# Epoch 26/600
# 14/14 [==============================] - 0s 29ms/step - loss: 0.2755 - val_loss: 0.1870
# Epoch 27/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2639 - val_loss: 0.1884
# Epoch 28/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2511 - val_loss: 0.1755
# Epoch 29/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2716 - val_loss: 0.1765
# Epoch 30/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2886 - val_loss: 0.1724
# Epoch 31/600
# 14/14 [==============================] - 0s 27ms/step - loss: 0.2326 - val_loss: 0.1633
# Epoch 32/600
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2482 - val_loss: 0.1618
# Epoch 33/600
# 14/14 [==============================] - 1s 61ms/step - loss: 0.2317 - val_loss: 0.1575
# Epoch 34/600
# 14/14 [==============================] - 0s 29ms/step - loss: 0.2471 - val_loss: 0.1572
# Epoch 35/600
# 14/14 [==============================] - 0s 23ms/step - loss: 0.2539 - val_loss: 0.1457
# Epoch 36/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2305 - val_loss: 0.1416
# Epoch 37/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.2259 - val_loss: 0.1489
# Epoch 38/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.2124 - val_loss: 0.1368
# Epoch 39/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.2232 - val_loss: 0.1417
# Epoch 40/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2032 - val_loss: 0.1361
# Epoch 41/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1915 - val_loss: 0.1338
# Epoch 42/600
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1940 - val_loss: 0.1288
# Epoch 43/600
# 14/14 [==============================] - 0s 23ms/step - loss: 0.2037 - val_loss: 0.1311
# Epoch 44/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1750 - val_loss: 0.1257
# Epoch 45/600
# 14/14 [==============================] - 0s 35ms/step - loss: 0.1852 - val_loss: 0.1229
# Epoch 46/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.
600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1094 - val_loss: 0.1027
# Epoch 102/600
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0997 - val_loss: 0.0935
# Epoch 103/600
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1121 - val_loss: 0.0917
# Epoch 104/600
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0878 - val_loss: 0.0973
# Epoch 105/600
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1131 - val_loss: 0.1032
# Epoch 106/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0833 - val_loss: 0.0930
# Epoch 107/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1047 - val_loss: 0.0859
# Epoch 108/600
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1003 - val_loss: 0.1044
# Epoch 109/600
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0913 - val_loss: 0.0849
# Epoch 110/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0953 - val_loss: 0.0975
# Epoch 111/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1039 - val_loss: 0.0916
# Epoch 112/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1022 - val_loss: 0.0924
# Epoch 113/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1085 - val_loss: 0.1063
# Epoch 114/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 115/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1033 - val_loss: 0.0984
# Epoch 116/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0957 - val_loss: 0.0924
# Epoch 117/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0771 - val_loss: 0.1108
# Epoch 118/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1067 - val_loss: 0.0879
# Epoch 119/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0852 - val_loss: 0.0838
# Epoch 120/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0919 - val_loss: 0.0934
# Epoch 121/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0990 - val_loss: 0.1016
# Epoch 122/600
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1141 - val_loss: 0.0880
# Epoch 123/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1004 - val_loss: 0.1051
# Epoch 124/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0796 - val_loss: 0.0894
# Epoch 125/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0954 - val_loss: 0.1016
# Epoch 126/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0907 - val_loss: 0.0907
# Epoch 127/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0922 - val_loss: 0.0908
# Epoch 128/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0840 - val_loss: 0.0955
# Epoch 129/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0739 - val_loss: 0.1046
# Epoch 130/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0822 - val_loss: 0.1026
# Epoch 131/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0772 - val_loss: 0.1046
# Epoch 132/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0739 - val_loss: 0.0926
# Epoch 133/600
# 14/14 [==============================] - 1s 43ms/step - loss: 0.1017 - val_loss: 0.0866
# Epoch 134/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0826 - val_loss: 0.1297
# Epoch 135/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0715 - val_loss: 0.0968
# Epoch 136/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 137/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0829 - val_loss: 0.1109
# Epoch 138/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0997 - val_loss: 0.1012
# Epoch 139/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0838 - val_loss: 0.1057
# Epoch 140/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1015 - val_loss: 0.0920
# Epoch 141/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0812 - val_loss: 0.0959
# Epoch 142/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0886 - val_loss: 0.1025
# Epoch 143/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0889 - val_loss: 0.1145
# Epoch 144/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0914 - val_loss: 0.0916
# Epoch 144: early stopping

# %% [markdown]
# # Running Tensorboard

# %% [markdown]
# ## Running through the Command Line
#
# **Watch video to see how to run Tensorboard through a command line call.**

# %% [markdown]
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)

# %%
print(log_directory)
# Out:
# logs\fit

# %%
pwd
# Out:
# 'C:\\Users\\Marcial\\Pierian-Data-Courses\\TensorFlow-Two-Bootcamp\\03-ANNs'

# %% [markdown]
# ### Use cd at your command line to change directory to the file path reported back by pwd or your current .py file location.
# ### Then run this code at your command line or terminal

# %%
tensorboard --logdir logs\fit
